# %% [markdown]
# # Stage 5: Evaluation
#
# **Objective:** OOD cross-dataset generalization tests, fairness metrics (demographic parity, equalized odds), shortcut-suppression delta (Δ accuracy when shortcuts removed), clinical validity assessment.
#
# **Tools:** `scikit-fairness`, HuggingFace `evaluate`, `checklist`, human annotation study protocol
